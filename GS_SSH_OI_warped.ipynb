# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pytorch_lightning as pl
from torch.distributions import Bernoulli
import xarray as xr
import xrft
import numpy as np
import matplotlib.pyplot as plt
import src.data
import src.utils
from scipy.stats import multivariate_normal
import pandas as pd
import functools as ft
from collections import namedtuple
from IPython.display import Markdown, display
from omegaconf import OmegaConf
import yaml
import inspect
import hydra
import os
from matplotlib.gridspec import GridSpec
from matplotlib.animation import FuncAnimation, PillowWriter
import matplotlib.colors as colors
from matplotlib.colors import LogNorm 
from matplotlib.animation import FuncAnimation
import matplotlib.pyplot as plt
from PIL import Image
import kornia.filters as kfilts
from torch.cuda.amp import autocast, GradScaler
from scipy.ndimage import gaussian_filter
from scipy.ndimage import binary_dilation
from skimage.morphology import disk, dilation
from sklearn.linear_model import LinearRegression

device = torch.device("cuda:6" if torch.cuda.is_available() else "cpu")
#device = "cpu"

# %% [markdown]
# # Utils Functions

# %%
def plot_tensor(tensor, title = 'Logits Plot'):
    pos_tensor_numpy = tensor.numpy()
    plt.imshow(pos_tensor_numpy, cmap='viridis', interpolation='nearest')
    plt.colorbar()
    plt.title(title)
    plt.show()

def rmse_based_scores_from_ds(ds, ref_variable='tgt', study_variable='out'):
    #mask = ~np.isnan(ds['input'])
    try:
        return rmse_based_scores(ds[ref_variable], ds[study_variable])[2:]
    except:
        return [np.nan, np.nan]

def psd_based_scores_from_ds(ds, ref_variable='tgt', study_variable='out'):
    print(ds)
    try:
        return psd_based_scores(ds[ref_variable], ds[study_variable])[1:]
    except:
        return [np.nan, np.nan]

def rmse_based_scores_lead(da_rec, da_ref):
    rmse_t = (
        1.0
        - (((da_rec - da_ref) ** 2).mean(dim=("lon", "lat"))) ** 0.5
        / (((da_ref) ** 2).mean(dim=("lon", "lat"))) ** 0.5
    )
    rmse_xy = (((da_rec - da_ref) ** 2).mean(dim=("time"))) ** 0.5
    rmse_t = rmse_t.rename("rmse_t")
    rmse_xy = rmse_xy.rename("rmse_xy")
    reconstruction_error_stability_metric = rmse_t.std().values
    leaderboard_rmse = (
        1.0 - (((da_rec - da_ref) ** 2).mean()) ** 0.5 / (((da_ref) ** 2).mean()) ** 0.5
    )
    return (
        np.round(leaderboard_rmse.values, 5).item(),
        np.round(reconstruction_error_stability_metric, 5).item(),
    )

def rmse_based_scores_day(da_rec, da_ref):
    # Calculate leaderboard RMSE
    leaderboard_rmse = (
        1.0 - (((da_rec - da_ref) ** 2).mean()) ** 0.5 / (((da_ref) ** 2).mean()) ** 0.5
    )
    return np.round(leaderboard_rmse.values, 5).item()

def rmse_based_scores(da_rec, da_ref):
    rmse_t = (
        1.0
        - (((da_rec - da_ref) ** 2).mean(dim=("lon", "lat"))) ** 0.5
        / (((da_ref) ** 2).mean(dim=("lon", "lat"))) ** 0.5
    )
    rmse_xy = (((da_rec - da_ref) ** 2).mean(dim=("time"))) ** 0.5
    rmse_t = rmse_t.rename("rmse_t")
    rmse_xy = rmse_xy.rename("rmse_xy")
    reconstruction_error_stability_metric = rmse_t.std().values
    leaderboard_rmse = (
        1.0 - (((da_rec - da_ref) ** 2).mean()) ** 0.5 / (((da_ref) ** 2).mean()) ** 0.5
    )
    return (
        rmse_t,
        rmse_xy,
        np.round(leaderboard_rmse.values, 5).item(),
        np.round(reconstruction_error_stability_metric, 5).item(),
    )


def psd_based_scores(da_rec, da_ref):
    print('hello')
    err = da_rec - da_ref
    err["time"] = (err.time - err.time[0]) / np.timedelta64(1, "D")
    signal = da_ref
    signal["time"] = (signal.time - signal.time[0]) / np.timedelta64(1, "D")
    psd_err = xrft.power_spectrum(
        err, dim=["time", "lon"], detrend="constant", window="hann"
    ).compute()
    psd_signal = xrft.power_spectrum(
        signal, dim=["time", "lon"], detrend="constant", window="hann"
    ).compute()

    mean_psd_signal = psd_signal.mean(dim="lat").where(
        (psd_signal.freq_lon > 0.0) & (psd_signal.freq_time > 0), drop=True
    )
    
    mean_psd_err = psd_err.mean(dim="lat").where(
        (psd_err.freq_lon > 0.0) & (psd_err.freq_time > 0), drop=True
    )
    print(mean_psd_err)
    psd_based_score = 1.0 - mean_psd_err / mean_psd_signal
    level = [0.5]
    cs = plt.contour(
        1.0 / psd_based_score.freq_lon.values,
        1.0 / psd_based_score.freq_time.values,
        psd_based_score,
        level,
    )
    x05, y05 = cs.collections[0].get_paths()[0].vertices.T
    plt.close()

    shortest_spatial_wavelength_resolved = np.min(x05)
    shortest_temporal_wavelength_resolved = np.min(y05)
    psd_da = 1.0 - mean_psd_err / mean_psd_signal
    psd_da.name = "psd_score"
    return (
        psd_da.to_dataset(),
        np.round(shortest_spatial_wavelength_resolved, 3).item(),
        np.round(shortest_temporal_wavelength_resolved, 3).item(),
    )

def weighted_mse(err, weight = None):
    if weight is None:
        err_w = err
        non_zeros = (torch.ones_like(err) == 0.0)
    else:
        err_w = err * weight[None, ...]
        non_zeros = (torch.ones_like(err) * weight[None, ...]) == 0.0
    err_num = err.isfinite() & ~non_zeros
    if err_num.sum() == 0:
        return torch.scalar_tensor(1000.0, device=err_num.device).requires_grad_()
    loss = F.mse_loss(err_w[err_num], torch.zeros_like(err_w[err_num]))
    return loss

def pprint_cfg(cfg):
    display(Markdown("""```yaml\n\n""" +yaml.dump(OmegaConf.to_container(cfg), default_flow_style=None, indent=2)+"""\n\n```"""))


def update_dz_fig(frame, da, da_4dVN):
    plt.clf()  # Clear the previous frame
    global_min = np.min([da[frame, :, :], da_4dVN[frame, :, :]])
    global_max = np.max([da[frame, :, :], da_4dVN[frame, :, :]])
    
    mu_4dVN = rmse_based_scores_day(da[frame, :, :], da_4dVN[frame, :, :])

    corr_da_4dVN = xr.corr(da[frame, :, :], da_4dVN[frame, :, :])

    # Ground truth
    ax0 = fig.add_subplot(gs[0])
    im0 = ax0.imshow(da[frame, :, :] + 1, extent=[-60, -54, 32, 38], cmap='viridis', vmin=global_min, vmax=global_max)
    ax0.text(0.5, 1.05, 'Ground truth', ha='center', va='bottom', transform=ax0.transAxes, fontsize=14)

    title_4dVarNet = '4dVarNet'
    subtitle_4dVarNet = f'Correlation: {corr_da_4dVN:.2f}\nRMSE Score: {mu_4dVN:.2f}'

    # 4dVarNet
    ax2 = fig.add_subplot(gs[1])
    im2 = ax2.imshow(da_4dVN[frame, :, :] + 1, extent=[-60, -54, 32, 38], cmap='viridis', vmin=global_min, vmax=global_max)
    ax2.text(0.5, 1.1, title_4dVarNet, ha='center', va='bottom', transform=ax2.transAxes, fontsize=14)
    ax2.text(0.5, 1.01, subtitle_4dVarNet, ha='center', va='bottom', transform=ax2.transAxes, fontsize=10, linespacing=1.5)

    # Colorbar
    ax3 = fig.add_subplot(gs[2])
    plt.colorbar(im2, cax=ax3, label='ECS')

    ax3_position = ax3.get_position()
    new_position = [ax3_position.x0 - 0.03, ax3_position.y0, ax3_position.width, ax3_position.height]
    ax3.set_position(new_position)

# %% [markdown]
# # Field Selection

# %%
tgt_ds_ecs = xr.open_dataset('/Odyssey/public/natl60/celerity/NATL60GULF-CJM165_cutoff_freq_regrid_0_1000m.nc')
tgt_ds = xr.open_dataset('natl_gf_w_5nadirs.nc')
time_step = '2012-11-13T12:00:00.000000000'  # Example time step
inp_da = tgt_ds.ssh.sel(time=time_step)
#inp_da = tgt_ds_ecs.ecs.sel(time=time_step)
inp_da.plot()
plt.title(f"Sample Values at Time Step {time_step}")
plt.show()

lat_shape = len(inp_da.lat)
lon_shape = len(inp_da.lon)

crop_lat_start =  20
crop_lat_end = lat_shape -  20
crop_lon_start =  20
crop_lon_end = lon_shape -  20

inp_da_GS = inp_da.isel(lat=slice(crop_lat_start, crop_lat_end),
                     lon=slice(crop_lon_start, crop_lon_end))
lambda_value = 15.0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Odyssey/private/ochapron/ConcreteAE/natl_gf_w_5nadirs.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '8a39fd0a-8c3f-4232-b831-4f24ed0893ed']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 tgt_ds_ecs = xr.open_dataset('/Odyssey/public/natl60/celerity/NATL60GULF-CJM165_cutoff_freq_regrid_0_1000m.nc')
# ----> 2 tgt_ds = xr.open_dataset('natl_gf_w_5nadirs.nc')
#       3 time_step = '2012-11-13T12:00:00.000000000'  # Example time step
#       4 inp_da = tgt_ds.ssh.sel(time=time_step)
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/api.py:611, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     599 decoders = _resolve_decoders_kwargs(
#     600     decode_cf,
#     601     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     607     decode_coords=decode_coords,
#     608 )
#     610 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 611 backend_ds = backend.open_dataset(
#     612     filename_or_obj,
#     613     drop_variables=drop_variables,
#     614     **decoders,
#     615     **kwargs,
#     616 )
#     617 ds = _dataset_from_backend_dataset(
#     618     backend_ds,
#     619     filename_or_obj,
#    (...)
#     629     **kwargs,
#     630 )
#     631 return ds
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:649, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     628 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     629     self,
#     630     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     646     autoclose=False,
#     647 ) -> Dataset:
#     648     filename_or_obj = _normalize_path(filename_or_obj)
# --> 649     store = NetCDF4DataStore.open(
#     650         filename_or_obj,
#     651         mode=mode,
#     652         format=format,
#     653         group=group,
#     654         clobber=clobber,
#     655         diskless=diskless,
#     656         persist=persist,
#     657         lock=lock,
#     658         autoclose=autoclose,
#     659     )
#     661     store_entrypoint = StoreBackendEntrypoint()
#     662     with close_on_error(store):
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:410, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     404 kwargs = dict(
#     405     clobber=clobber, diskless=diskless, persist=persist, format=format
#     406 )
#     407 manager = CachingFileManager(
#     408     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     409 )
# --> 410 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:357, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     355 self._group = group
#     356 self._mode = mode
# --> 357 self.format = self.ds.data_model
#     358 self._filename = self.ds.filepath()
#     359 self.is_remote = is_remote_uri(self._filename)
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:419, in NetCDF4DataStore.ds(self)
#     417 @property
#     418 def ds(self):
# --> 419     return self._acquire()
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:413, in NetCDF4DataStore._acquire(self, needs_lock)
#     412 def _acquire(self, needs_lock=True):
# --> 413     with self._manager.acquire_context(needs_lock) as root:
#     414         ds = _nc4_require_group(root, self._group, self._mode)
#     415     return ds
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File /Odyssey/private/ochapron/miniconda/miniconda3/envs/fdv/lib/python3.10/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2470, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2107, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Odyssey/private/ochapron/ConcreteAE/natl_gf_w_5nadirs.nc'

# %% [markdown]
# # OI Code

# %%
def optimal_interpolation(data_with_nans, length_scale=15., sigma_f=1.0, sigma_n=0.1):
    """
    Perform optimal interpolation (kriging) on a 2D tensor with missing data (NaNs).

    Parameters:
    - data_with_nans (torch.Tensor): 2D tensor with missing values represented as NaN.
    - length_scale (float or torch.Tensor): Length scale parameter for the RBF kernel.
    - sigma_f (float or torch.Tensor): Signal variance parameter for the RBF kernel.
    - sigma_n (float or torch.Tensor): Noise variance parameter.

    Returns:
    - reconstructed_data (torch.Tensor): 2D tensor with missing values reconstructed.
    """
    device = data_with_nans.device
    H, W = data_with_nans.shape

    observed_indices = ~torch.isnan(data_with_nans)
    observed_positions = torch.nonzero(observed_indices, as_tuple=False).float()  # Positions (i, j)
    observed_values = data_with_nans[observed_indices].to(device)

    missing_indices = torch.isnan(data_with_nans)
    missing_positions = torch.nonzero(missing_indices, as_tuple=False).float()

    observed_positions_x = observed_positions[:, 1] #/ (W - 1) * 10  
    observed_positions_y = observed_positions[:, 0] #/ (H - 1) * 10  
    observed_coords = torch.stack([observed_positions_x, observed_positions_y], dim=1)

    missing_positions_x = missing_positions[:, 1] #/ (W - 1) * 10
    missing_positions_y = missing_positions[:, 0] #/ (H - 1) * 10
    missing_coords = torch.stack([missing_positions_x, missing_positions_y], dim=1)

    # Define the covariance function (RBF kernel)
    def cov_func(x1, x2, length_scale, sigma_f):
        """
        Compute the covariance matrix using the RBF kernel.
        """
        x1 = x1.unsqueeze(1)  # Shape: [N1, 1, 2]
        x2 = x2.unsqueeze(0)  # Shape: [1, N2, 2]
        sqdist = ((x1 - x2) ** 2).sum(dim=2)  # Shape: [N1, N2]
        return sigma_f ** 2 * torch.exp(-0.5 / length_scale ** 2 * sqdist)

    # Ensure hyperparameters are tensors on the correct device
    if not isinstance(length_scale, torch.Tensor):
        length_scale = torch.tensor(length_scale, device=device)
    if not isinstance(sigma_f, torch.Tensor):
        sigma_f = torch.tensor(sigma_f, device=device)
    if not isinstance(sigma_n, torch.Tensor):
        sigma_n = torch.tensor(sigma_n, device=device)

    # Compute covariance matrices
    K = cov_func(observed_coords, observed_coords, length_scale, sigma_f)
    K += sigma_n ** 2 * torch.eye(K.size(0), device=device)  # Add noise variance
    K_s = cov_func(observed_coords, missing_coords, length_scale, sigma_f)

    # Cholesky decomposition
    L = torch.cholesky(K + 1e-6 * torch.eye(K.size(0), device=device))  # Add jitter for numerical stability

    # Solve for alpha
    alpha = torch.cholesky_solve(observed_values.unsqueeze(1), L)

    # Predict mean at missing points
    mean_pred = K_s.t().matmul(alpha).squeeze()
    mean_pred = mean_pred.to(torch.float32)

    # Reconstruct the data tensor
    reconstructed_data = data_with_nans.clone()
    reconstructed_data[missing_indices] = mean_pred

    return reconstructed_data

# %%
def optimal_interpolation_3d(data_with_nans, length_scale_space=1., length_scale_time=1.0, sigma_f=1.0, sigma_n=0.1):
    """
    Perform optimal interpolation (kriging) on a 3D tensor with missing data (NaNs).
    This function handles spatiotemporal data (e.g., time, height, width).

    Parameters:
    - data_with_nans (torch.Tensor): 3D tensor with missing values represented as NaN.
    - length_scale_space (float or torch.Tensor): Spatial length scale parameter for the RBF kernel.
    - length_scale_time (float or torch.Tensor): Temporal length scale parameter for the RBF kernel.
    - sigma_f (float or torch.Tensor): Signal variance parameter for the RBF kernel.
    - sigma_n (float or torch.Tensor): Noise variance parameter.

    Returns:
    - reconstructed_data (torch.Tensor): 3D tensor with missing values reconstructed.
    """
    device = data_with_nans.device
    T, H, W = data_with_nans.shape

    # Extract observed data positions and values
    observed_indices = ~torch.isnan(data_with_nans)
    observed_positions = torch.nonzero(observed_indices, as_tuple=False).float()  # Positions (t, i, j)
    observed_values = data_with_nans[observed_indices].to(device)

    # Extract missing data positions
    missing_indices = torch.isnan(data_with_nans)
    missing_positions = torch.nonzero(missing_indices, as_tuple=False).float()

    # Map positions to coordinate space (consistent with data generation)
    # Normalize spatial coordinates to a consistent scale
    observed_positions_x = observed_positions[:, 2] / (W - 1) * 10  # Column indices to x-coordinates
    observed_positions_y = observed_positions[:, 1] / (H - 1) * 10  # Row indices to y-coordinates
    observed_positions_t = observed_positions[:, 0] / (T - 1) * 10  # Time indices to t-coordinates
    observed_coords = torch.stack([observed_positions_x, observed_positions_y, observed_positions_t], dim=1)

    missing_positions_x = missing_positions[:, 2] / (W - 1) * 10
    missing_positions_y = missing_positions[:, 1] / (H - 1) * 10
    missing_positions_t = missing_positions[:, 0] / (T - 1) * 10
    missing_coords = torch.stack([missing_positions_x, missing_positions_y, missing_positions_t], dim=1)

    # Define the spatiotemporal covariance function (RBF kernel)
    def cov_func(x1, x2, length_scale_space, length_scale_time, sigma_f):
        """
        Compute the covariance matrix using the spatiotemporal RBF kernel.
        """
        x1 = x1.unsqueeze(1)  # Shape: [N1, 1, 3]
        x2 = x2.unsqueeze(0)  # Shape: [1, N2, 3]
        # Separate spatial and temporal components
        spatial_sqdist = ((x1[..., :2] - x2[..., :2]) ** 2).sum(dim=2) / (length_scale_space ** 2)
        temporal_sqdist = ((x1[..., 2] - x2[..., 2]) ** 2) / (length_scale_time ** 2)
        sqdist = spatial_sqdist + temporal_sqdist  # Combined spatiotemporal distance
        return sigma_f ** 2 * torch.exp(-0.5 * sqdist)

    # Ensure hyperparameters are tensors on the correct device
    if not isinstance(length_scale_space, torch.Tensor):
        length_scale_space = torch.tensor(length_scale_space, device=device)
    if not isinstance(length_scale_time, torch.Tensor):
        length_scale_time = torch.tensor(length_scale_time, device=device)
    if not isinstance(sigma_f, torch.Tensor):
        sigma_f = torch.tensor(sigma_f, device=device)
    if not isinstance(sigma_n, torch.Tensor):
        sigma_n = torch.tensor(sigma_n, device=device)

    # Compute covariance matrices
    K = cov_func(observed_coords, observed_coords, length_scale_space, length_scale_time, sigma_f)
    K += sigma_n ** 2 * torch.eye(K.size(0), device=device)  # Add noise variance
    K_s = cov_func(observed_coords, missing_coords, length_scale_space, length_scale_time, sigma_f)

    # Cholesky decomposition
    L = torch.cholesky(K + 1e-6 * torch.eye(K.size(0), device=device))  # Add jitter for numerical stability

    # Solve for alpha
    alpha = torch.cholesky_solve(observed_values.unsqueeze(1), L)

    # Predict mean at missing points
    mean_pred = K_s.t().matmul(alpha).squeeze()
    mean_pred = mean_pred.to(torch.float32)

    # Reconstruct the data tensor
    reconstructed_data = data_with_nans.clone()
    reconstructed_data[missing_indices] = mean_pred

    return reconstructed_data

# %% [markdown]
# # Warped Field Perturbations

# %%
def generate_correlated_fields(N, L, T_corr, sigma, num_fields=10, device=device,seed=41):
    """
    Generate a series of 2D fields with both spatial and temporal correlations.

    Parameters:
        N (int): Grid size (assumed to be square, NxN).
        L (float): Spatial correlation length.
        T_corr (float): Temporal correlation length.
        sigma (float): Standard deviation of the field.
        num_fields (int): Number of fields to generate (default is 10).
        device (str): Device to run the computations on ('cpu' or 'cuda').

    Returns:
        torch.Tensor: Generated fields of shape (num_fields, N, N).
    """
    torch.manual_seed(seed)
    # Define the time points for the fields
    time_points = torch.linspace(0, num_fields - 1, num_fields, device=device)
    # Compute the temporal covariance matrix
    C_temporal = torch.exp(-abs(time_points[:, None] - time_points[None, :]) / T_corr)
    # Perform Cholesky decomposition to get the temporal correlation factors
    L_chol = torch.linalg.cholesky(C_temporal)
    # Generate independent Gaussian white noise for each time point
    white_noises = torch.randn((num_fields, N, N), device=device)
    # Combine white noise using the Cholesky factors to induce temporal correlation
    temporal_correlated_noises = torch.matmul(L_chol, white_noises.view(num_fields, -1)).view(num_fields, N, N)
    # Generate 2D grid of wavenumbers for spatial correlation
    kx = torch.fft.fftfreq(N, device=device) * N
    ky = torch.fft.fftfreq(N, device=device) * N
    k = torch.sqrt(kx[:, None]**2 + ky[None, :]**2)
    cutoff_mask = (k < 20).float()  # High-frequency cutoff
    # apply - if we apply the same approach to vorticity, and then obtain 
    # stream function, 
    # Spatial covariance (Power spectrum) for Gaussian covariance
    P_k = torch.exp(-0.5 * (k * L)**3)
    P_k[0, 0] = 0.0
    P_k = P_k / torch.sum(P_k)
    # Generate fields using Fourier transform
    fields = []
    for i in range(num_fields):
        noise_ft = torch.fft.fft2(temporal_correlated_noises[i])
        field_ft = noise_ft * sigma**2 * torch.sqrt(P_k) * cutoff_mask
        field = torch.fft.ifft2(field_ft).real
        fields.append(field)
    return torch.stack(fields)

N = lat_shape  # Grid size
L = 5.0  # Spatial correlation length
T_corr = 1.0  # Temporal correlation length
sigma = 25  # Standard deviation of the field

# Generate a Gaussian random field with a high-frequency cutoff
displacement_x = generate_correlated_fields(N, L, T_corr, sigma, device=device, seed=41)
displacement_y = generate_correlated_fields(N, L, T_corr, sigma, device=device, seed=41)
# fake_dx=torch.zeros_like(displacement_x)

# %%
# We now perturb the fields at the same way,
def warp_field(field, dx, dy):
    """
    Warp a 2D field based on displacement fields dx and dy.
    field (torch.Tensor): Input field of shape (batch_size, height, width)
    dx (torch.Tensor): X-displacement field of shape (batch_size, height, width)
    dy (torch.Tensor): Y-displacement field of shape (batch_size, height, width)
    """
    batch_size, _, height, width = field.shape
    
    # Create base grid
    y, x = torch.meshgrid(torch.arange(height), torch.arange(width), indexing='ij')
    base_grid = torch.stack((x, y), dim=-1).float()
    dx=dx.to(field.dtype)  # Adjust size as needed
    dy=dy.to(field.dtype) 
    # Add batch dimension and move to the same device as input field
    base_grid = base_grid.unsqueeze(0).repeat(batch_size,1,1,1).to(field.device)

    # Apply displacements
    sample_grid = base_grid + torch.stack((dx, dy), dim=-1)
    sample_grid[..., 0] = sample_grid[..., 0] % (width)
    sample_grid[..., 1] = sample_grid[..., 1] % (height)
    

    # Normalize grid to [-1, 1] range
    sample_grid[..., 0] = 2 * sample_grid[..., 0] / (width) - 1
    sample_grid[..., 1] = 2 * sample_grid[..., 1] / (height) - 1

    # Perform sampling
    warped_field = F.grid_sample(field, sample_grid, mode='bilinear', padding_mode='reflection', align_corners=False)
    return warped_field,torch.max(sample_grid), torch.min(sample_grid)

# %%
batch_size = 10
channels = 1

# Prepare data
mean_tgt = inp_da.mean().item()
std_tgt = inp_da.std().item()

tens_inp = torch.from_numpy(inp_da.values).float().to(device)
tens_inp = (tens_inp - mean_tgt) / std_tgt
tens_inp.unsqueeze_(0)

tens_inp = tens_inp.repeat(batch_size, 1, 1, 1)
# Create a sample field (e.g., a gradient)
field = tens_inp
displacement_x = displacement_x 
displacement_y = displacement_y
mean_x=torch.tensor(6.0)
mean_y=torch.tensor(5.0)

# Perform warping
warped_field,max_grid,min_grid = warp_field(field, displacement_x+mean_x, displacement_y+mean_y)

print(f"Input field shape: {field.shape}")
print(f"Warped field shape: {warped_field.shape}")
# Out:
# Input field shape: torch.Size([10, 1, 240, 240])
# Warped field shape: torch.Size([10, 1, 240, 240])

# %%
# Function to create a 2D Gaussian kernel
def gaussian_kernel(kernel_size=5, sigma=1.0, dtype=torch.float32, device='cuda'):
    # Create a 2D grid of coordinates (x, y)
    x = torch.arange(kernel_size, dtype=dtype, device=device) - (kernel_size - 1) / 2
    y = torch.arange(kernel_size, dtype=dtype, device=device) - (kernel_size - 1) / 2
    xx, yy = torch.meshgrid(x, y)

    # Compute the Gaussian function on the grid
    kernel = torch.exp(-(xx**2 + yy**2) / (2 * sigma**2))

    # Normalize the kernel to ensure the sum of the weights is 1
    kernel = kernel / kernel.sum()
    return kernel

# Function to apply Gaussian smoothing to a batch of images
def apply_gaussian_smoothing(input_tensor, kernel_size=15, sigma=1.0):
    dtype = input_tensor.dtype
    device = input_tensor.device
    kernel = gaussian_kernel(kernel_size, sigma, dtype=dtype, device=device)
    
    # Reshape the kernel to be [1, 1, kernel_size, kernel_size] (for 2D convolution)
    kernel = kernel.view(1, 1, kernel_size, kernel_size)

    # Expand the kernel to apply it across all channels and the batch
    kernel = kernel.expand(1, 1, kernel_size, kernel_size)

    padding=kernel_size//2
    # Pad the input tensor with circular padding
    padded_input = F.pad(input_tensor, (padding, padding, padding, padding), mode='reflect')

    # Apply the convolution (use groups=batch_size to apply the kernel individually per batch element)
    smoothed_tensor = F.conv2d(padded_input, kernel, groups=1)

    # Remove the extra channel dimension
    return smoothed_tensor

# %%
# Smmothing
smoothed_tensor=apply_gaussian_smoothing(warped_field,kernel_size=10,sigma=1.5)
# Out:
# /Odyssey/private/ochapron/miniconda/miniconda3/envs/4dvarnet-starter/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343964576/work/aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# We now generate a spatially correlated gaussian random field that we can
plt.figure(figsize=(16, 5))

for i in range(5):
    plt.subplot(2, 5, i + 1)
    plt.imshow(displacement_x[i].cpu().numpy(), cmap='PuOr')
    plt.colorbar()
    plt.title(f"grf at t={i+1}")

for i in range(5, 10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(displacement_x[i].cpu().numpy(), cmap='PuOr')
    plt.colorbar()
    plt.title(f"grf at t={i+1}")

plt.show()

# %%
# # Plot the column wise field 
# #specific_levels=[-4,-2,0,2,4]
# plt.figure(figsize=(22,14))
# for i in range(4):
#     plt.subplot(3,4,i+1)
#     plt.imshow(field[i,0].cpu().numpy(), cmap='RdBu')
#     plt.colorbar()
#     #plt.contour(field[i,0].cpu().numpy(), levels=specific_levels, colors='white', linewidths=1.5, origin='lower')
#     plt.title(f'true field at t={i}')

#     plt.subplot(3,4,5+i)
#     plt.imshow(warped_field[i,0].cpu().numpy()- field[i,0].cpu().numpy(), cmap='RdBu')
#     plt.colorbar()
#     plt.title(f'perturbed field at t={i}')
#     #plt.contour(warped_field[i,0].cpu().numpy(), levels=specific_levels, colors='white', linewidths=1.5, origin='lower')

#     plt.subplot(3,4,9+i)
#     plt.imshow(smoothed_tensor[i,0].cpu().numpy(), cmap='RdBu')
#     plt.colorbar()
#     plt.title(f'smoothed field x at t={i}')
#     #plt.contour(smoothed_tensor[i,0].cpu().numpy(), levels=specific_levels, colors='white', linewidths=1.5, origin='lower')

# %%
border_size = 20

plt.figure(figsize=(22,14))
for i in range(4):
    plt.subplot(4,4,i+1)
    plt.imshow(field[i,0,border_size:-border_size,border_size:-border_size].cpu().numpy(), cmap='RdBu')
    plt.colorbar()
    plt.title(f'true field at t={i}')

    plt.subplot(4,4,5+i)
    plt.imshow(warped_field[i,0,border_size:-border_size,border_size:-border_size].cpu().numpy(), cmap='RdBu')
    plt.colorbar()
    plt.title(f'perturbed field at t={i}')

    plt.subplot(4,4,9+i)
    plt.imshow(smoothed_tensor[i,0,border_size:-border_size,border_size:-border_size].cpu().numpy(), cmap='RdBu')
    plt.colorbar()
    plt.title(f'smoothed field x at t={i}')

    plt.subplot(4,4,13+i)
    plt.imshow(np.abs(warped_field[i,0,border_size:-border_size,border_size:-border_size].cpu().numpy() - field[i,0,border_size:-border_size,border_size:-border_size].cpu().numpy()), cmap='RdBu')
    plt.colorbar()
    plt.title(f'error field x at t={i}')

# %% [markdown]
# # GS Model

# %%
class GSModel(nn.Module):
    def __init__(self, time, lat, lon, rate, device):
        super(GSModel, self).__init__()
        self.logits = nn.Parameter(torch.zeros((2, time, lat, lon)))
        #self.logits = torch.zeros((2, time, lat, lon))
        self.logits.data[1, :, :, :] = np.log(rate / (1 - rate))
        self.time_window, self.lat, self.lon  = time, lat, lon
        self.device = device
        #self.length_scale = torch.tensor(22.0) 
        self.length_scale = nn.Parameter(torch.tensor(25.0))
        
    def gumbel_softmax(self, logits, tau=1.0, hard=False):
        gumbels = -torch.empty_like(logits, memory_format=torch.legacy_contiguous_format).exponential_().log()  # ~Gumbel(0,1)
        gumbels = (logits + gumbels) / tau  # ~Gumbel(logits,tau)
        y_soft = gumbels.softmax(dim=0)
        if hard:
            index = y_soft.max(dim=0, keepdim=True)[1]
            y_hard = torch.zeros_like(logits, memory_format=torch.legacy_contiguous_format).scatter_(dim=0, index=index, value=1.0)
            ret = y_hard - y_soft.detach() + y_soft
        else:
            ret = y_soft
        return ret

    def compute_logits_loss(self, logits_init, batch, budget_obs = 0.01, tau=1.0, weight=1.0, hard=True):
        tgt_inp = batch.tgt.clone()
        logits = logits_init.to(self.device)
    
        # Generate mask using Gumbel-Softmax
        gs_output = F.gumbel_softmax(logits, tau=tau, hard=hard, dim=0)[0, :, :, :]
        mask_input = gs_output.view(self.time_window,self.lat, self.lon)
        mask_input = mask_input.unsqueeze(0)  # Add batch dimension if necessary
        normalized_selected_points = mask_input.mean()
        # Create mask for observed data
        mask = mask_input
        # Apply mask to target input
        selected_tgt_inp = tgt_inp * mask
        selected_tgt_inp[mask == 0] = float('nan')
        # Perform optimal interpolation
        #output = optimal_interpolation(selected_tgt_inp[0,0])
        output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=self.length_scale)
        #mean_tgt = output.mean().item()
        #std_tgt = output.std().item()
        output = output.unsqueeze(0)
        output = output.unsqueeze(0)

        # Ensure the data types match
        output = output.to(tgt_inp.dtype)

        # Compute loss
        #loss_mse = weighted_mse(output - batch.tgt, lit_mod.rec_weight)
        # Define the padding size
        padding_size = 10  # Adjust this value as needed
        # Create a mask for the center region
        center_mask = torch.zeros_like(output)
        center_mask[:,:, padding_size:-padding_size, padding_size:-padding_size] = 1

        # Apply the center mask to the output and target
        output_center = output #* center_mask
        tgt_center = batch.tgt #* center_mask
        #output_center = (output_center - mean_tgt) / std_tgt
        #tgt_center = (tgt_center - mean_tgt) / std_tgt
        # Compute loss only for the center region
        loss_mse = F.mse_loss(output_center, tgt_center)

        # Compute normalized selected points
        valid_points_mask = ~torch.isnan(selected_tgt_inp)
        num_non_nan_elements = valid_points_mask.float().sum()
        total_points = mask.numel()
        #normalized_selected_points = num_non_nan_elements / total_points
        if normalized_selected_points >= budget_obs:
            weight = weight
        else:
            weight = 0
        loss = loss_mse + weight*normalized_selected_points
        return output, loss, mask_input, normalized_selected_points, loss_mse

    def normalize_logits(self):
        norm = self.logits.norm(p=2, dim=0, keepdim=True)
        self.logits.data = self.logits.data / norm

    def forward(self, batch, budget_obs, tau, weight, n_draw):
        total_loss = 0
        total_points = 0
        total_mse = 0
        for _ in range(n_draw):
            output, loss_draw, mask, normalized_selected_points, loss_mse = self.compute_logits_loss(self.logits, batch, budget_obs=budget_obs, tau=tau, weight=weight, hard=True)
            total_loss += loss_draw
            total_points += normalized_selected_points
            total_mse += loss_mse
            del output, mask
        mean_loss = total_loss / n_draw
        mean_points = total_points / n_draw
        mean_mse = total_mse / n_draw
        #print(self.length_scale)
        return mean_loss, mean_points, mean_mse, self.length_scale

# %%
class GSModel_T(nn.Module):
    def __init__(self, time, lat, lon, rate, device):
        super(GSModel_T, self).__init__()
        self.logits = nn.Parameter(torch.zeros((2, time, lat, lon)))
        self.logits.data[1, :, :, :] = np.log(rate / (1 - rate))
        self.time_window, self.lat, self.lon  = time, lat, lon
        self.device = device

    def gumbel_softmax(self, logits, tau=1.0, hard=False):
        gumbels = -torch.empty_like(logits, memory_format=torch.legacy_contiguous_format).exponential_().log()  # ~Gumbel(0,1)
        gumbels = (logits + gumbels) / tau  # ~Gumbel(logits,tau)
        y_soft = gumbels.softmax(dim=0)
        if hard:
            index = y_soft.max(dim=0, keepdim=True)[1]
            y_hard = torch.zeros_like(logits, memory_format=torch.legacy_contiguous_format).scatter_(dim=0, index=index, value=1.0)
            ret = y_hard - y_soft.detach() + y_soft
        else:
            ret = y_soft
        return ret

    def compute_logits_loss(self, logits_init, batch, budget_obs = 0.01, tau=1.0, weight=1.0, hard=True):
        tgt_inp = batch.tgt.clone()
        logits = logits_init.to(self.device)
    
        # Generate mask using Gumbel-Softmax
        gs_output = F.gumbel_softmax(logits, tau=tau, hard=hard, dim=0)[0, :, :, :]
        mask_input = gs_output.view(self.time_window, self.lat, self.lon)
        mask_input = mask_input.unsqueeze(0)  # Add batch dimension if necessary
        normalized_selected_points = mask_input.mean()
        # Create mask for observed data
        mask = mask_input
        # Apply mask to target input
        selected_tgt_inp = tgt_inp * mask
        selected_tgt_inp[mask == 0] = float('nan')

        # Perform optimal interpolation
        output = optimal_interpolation_3d(selected_tgt_inp[0])

        output = output.unsqueeze(0)
        # Ensure the data types match
        output = output.to(tgt_inp.dtype)

        # Compute loss
        #loss_mse = weighted_mse(output - batch.tgt, lit_mod.rec_weight)
        # Define the padding size
        padding_size = 10  # Adjust this value as needed
        # Create a mask for the center region
        center_mask = torch.zeros_like(output)
        center_mask[:,:, padding_size:-padding_size, padding_size:-padding_size] = 1

        # Apply the center mask to the output and target
        output_center = output * center_mask
        tgt_center = batch.tgt * center_mask

        # Compute loss only for the center region
        loss_mse = F.mse_loss(output_center, tgt_center)

        # Compute normalized selected points
        valid_points_mask = ~torch.isnan(selected_tgt_inp)

        #normalized_selected_points = num_non_nan_elements / total_points
        if normalized_selected_points >= budget_obs:
            weight = weight
        else:
            weight = 0
        loss = loss_mse + weight*normalized_selected_points
        return output, loss, mask_input, normalized_selected_points, loss_mse

    def normalize_logits(self):
        norm = self.logits.norm(p=2, dim=0, keepdim=True)
        self.logits.data = self.logits.data / norm

    def forward(self, batch, budget_obs, tau, weight, n_draw):
        total_loss = 0
        total_points = 0
        total_mse = 0
        for _ in range(n_draw):
            output, loss_draw, mask, normalized_selected_points, loss_mse = self.compute_logits_loss(self.logits, batch, budget_obs=budget_obs, tau=tau, weight=weight, hard=True)
            total_loss += loss_draw
            total_points += normalized_selected_points
            total_mse += loss_mse
            del output, mask
        mean_loss = total_loss / n_draw
        mean_points = total_points / n_draw
        mean_mse = total_mse / n_draw
        return mean_loss, mean_points, mean_mse

# %% [markdown]
# # Optimization loop

# %%
if len(inp_da_GS.shape) < 3:
    time= 1
    lat, lon =  inp_da_GS.shape
else:
    time, lat, lon = inp_da_GS.shape
print(inp_da_GS.shape)

n_draw = 15
n_iter = 1000
rate = 0.999
budget_obs = 1 - 0.999
accumulation_steps = 4

warmup_iterations =  100
delta_weight = 0.1
max_weight = 10.0

# Initialize model
model = GSModel(time, lat, lon,  rate, device).to(device)

# Prepare data
mean_tgt = inp_da_GS.mean().item()
std_tgt = inp_da_GS.std().item()

TrainingItem = namedtuple('TrainingItem', ['input', 'tgt'])

tens_inp_da = torch.from_numpy(inp_da_GS.values).float().to(device)
tens_inp_da = (tens_inp_da - mean_tgt) / std_tgt
tens_inp_da = tens_inp_da.unsqueeze(0)
tens_inp_da = tens_inp_da.unsqueeze(0)
tens_inp_da.requires_grad_(True)

batch = TrainingItem(input=tens_inp_da, tgt=tens_inp_da)

start_temp = 1.0
min_temp = 0.1
alpha = 0.9
lr = 1e-1
temperature = start_temp
mean_loss_list = []
mean_points_list = []
mean_mse_list = []
length_scale_list =[]

decay_rate = (min_temp / start_temp) ** (1 / (n_iter - 1))

# Initialize optimizer
optimizer = optim.Adam(model.parameters(), lr=lr)
scaler = GradScaler()

# Define pooling layer
pooling_layer = nn.AvgPool2d(kernel_size=3, stride=1, padding=1)

# Training loop
for k in range(n_iter):
    optimizer.zero_grad()
    total_points = 0
    total_mse = 0
    #weight = (1/1)*(k/n_iter)
    # Adjust weight based on the current iteration
    if k < warmup_iterations:
        weight = 0
    else:
        # Calculate weight incrementally after warmup
        weight = min((k - warmup_iterations + 1) * delta_weight, max_weight)
    for i in range(accumulation_steps):
        with autocast():  # Mixed precision training
            mean_loss, normalized_selected_points, loss_mse, length_scale = model(batch, budget_obs=budget_obs, tau=temperature, n_draw=n_draw, weight = weight)
            mean_loss = mean_loss / accumulation_steps  # Normalize loss by accumulation steps
            #mean_loss = mean_loss / accumulation_steps  # Normalize loss by accumulation steps
            total_points += normalized_selected_points / accumulation_steps  # Accumulate normalized points
            total_mse += loss_mse / accumulation_steps  # Accumulate MSE loss

        scaler.scale(mean_loss).backward()
        #pooled_logits = pooling_layer(model.logits)
        #upsampled_logits = F.interpolate(pooled_logits, size=model.logits.shape[2:], mode='bilinear', align_corners=False)
        #model.logits.data.copy_(upsampled_logits)
    #norm = model.logits.norm(p=2, dim=0, keepdim=True)
    #model.logits.data = np.log(rate / (1 - rate)) *(model.logits.data / norm)    
    #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.4)
    
    scaler.step(optimizer)
    scaler.update()
    #print(model.logits.grad)

    mean_loss_list.append(mean_loss.item())
    mean_points_list.append(total_points.item())
    mean_mse_list.append(total_mse.item())

    # print(f"Iteration {k}:")
    # print(f"  Mean Loss: {mean_loss.item()}")
    # print(f"  Weight: {weight}")
    # print(f"  Mean Normalized Selected Points: {total_points.item()}")
    # print(f"  Mean MSE Loss: {total_mse.item()}")
    
    temperature = start_temp * (min_temp / start_temp) ** (1 / (n_iter - 1)) 
    #temperature = max(min_temp, temperature * decay_rate)
    if (k + 1) % 250 == 0:
        plt.figure(figsize=(10, 5))
        plt.title(f'Logits distribution at epoch {k + 1}')
        plt.imshow(1 - 1 / (1 + np.exp(-model.logits[1, 0, :, :].detach().cpu().numpy())), cmap='viridis', interpolation='nearest', vmin=0, vmax=1)
        plt.colorbar()
        plt.show()
    #torch.cuda.empty_cache()
    length_scale_list.append(length_scale.detach().cpu().numpy())
    
# Plot mean loss
plt.figure(figsize=(10, 5))
plt.plot(mean_loss_list, label='Mean Model Loss')
plt.xlabel('Iteration')
plt.ylabel('Mean Model Loss')
plt.title('Mean Model Loss Over Iterations')
plt.legend()
plt.show()

# Plot mean normalized selected points
plt.figure(figsize=(10, 5))
plt.plot(mean_points_list, label='Mean Normalized Selected Points')
plt.xlabel('Iteration')
plt.ylabel('Mean Normalized Selected Points')
plt.title('Mean Normalized Selected Points Over Iterations')
plt.legend()
plt.show()

# Plot mean MSE loss
plt.figure(figsize=(10, 5))
plt.plot(mean_mse_list, label='Mean RMSE Loss')
plt.xlabel('Iteration')
plt.ylabel('Mean RMSE Loss')
plt.title('Mean RMSE Loss Over Iterations')
plt.legend()
plt.show()

# Plot mean MSE loss
plt.figure(figsize=(10, 5))
plt.plot(length_scale_list, label='Length scale')
plt.xlabel('Iteration')
plt.ylabel('Length scale')
plt.title('Length scale Over Iterations')
plt.legend()
plt.show()

# Visualization code (unchanged)
tensor_tgt = batch.tgt[0,0].detach().cpu().numpy()
da = xr.DataArray(tensor_tgt, dims=inp_da_GS.dims, coords=inp_da_GS.coords)
da = da * std_tgt + mean_tgt

plt.figure(figsize=(10, 5))
plt.title('Observation probability after training')
plt.imshow(1 - 1 / (1 + np.exp(-model.logits[1, 0, :, :].detach().cpu().numpy())), cmap='viridis', interpolation='nearest', vmin=0, vmax=1)
plt.colorbar()
plt.show()

logits_init = (torch.zeros((2, time, lat, lon)))
logits_init.data[1, :, :, :] = np.log(rate / (1 - rate))
plt.figure(figsize=(10, 5))
plt.title('Observation probability before training')
plt.imshow(1 - 1 / (1 + np.exp(-logits_init[1, 0, :, :].detach().cpu().numpy())), cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.figure(figsize=(10, 5))
da.plot()
plt.title(f"Sample Values at Time Step {time_step}")
plt.show()
# Out:
# (200, 200)
# /tmp/ipykernel_2166340/1854639517.py:56: UserWarning: torch.cholesky is deprecated in favor of torch.linalg.cholesky and will be removed in a future PyTorch release.
# L = torch.cholesky(A)
# should be replaced with
# L = torch.linalg.cholesky(A)
# and
# U = torch.cholesky(A, upper=True)
# should be replaced with
# U = torch.linalg.cholesky(A).mH().
# This transform will produce equivalent results for all valid (symmetric positive definite) inputs. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343964576/work/aten/src/ATen/native/BatchLinearAlgebra.cpp:1691.)
#   L = torch.cholesky(K + 1e-6 * torch.eye(K.size(0), device=device))  # Add jitter for numerical stability

# %%
results = []

for i in range(warped_field.shape[0]):
    inp_da_GS_warped = warped_field[i, 0, 20:220, 20:220]
    print(inp_da_GS_warped.shape)
    if len(inp_da_GS_warped.shape) < 3:
        time = 1
        lat, lon = inp_da_GS_warped.shape
    else:
        time, lat, lon = inp_da_GS_warped.shape

    n_draw = 15
    n_iter = 1000
    rate = 0.999
    budget_obs = 1 - 0.999
    accumulation_steps = 4

    warmup_iterations = 100
    delta_weight = 0.1
    max_weight = 10.0

    # Initialize model
    model = GSModel(time, lat, lon, rate, device).to(device)

    # Prepare data
    mean_tgt = inp_da_GS_warped.mean().item()
    std_tgt = inp_da_GS_warped.std().item()

    TrainingItem = namedtuple('TrainingItem', ['input', 'tgt'])

    tens_inp_da_warped = inp_da_GS_warped
    tens_inp_da_warped = (tens_inp_da_warped - mean_tgt) / std_tgt
    tens_inp_da_warped = tens_inp_da_warped.unsqueeze(0)
    tens_inp_da_warped = tens_inp_da_warped.unsqueeze(0)
    tens_inp_da_warped.requires_grad_(True)
    batch = TrainingItem(input=tens_inp_da_warped, tgt=tens_inp_da_warped)

    start_temp = 1.0
    min_temp = 0.1
    alpha = 0.9
    lr = 1e-1
    temperature = start_temp
    mean_loss_list = []
    mean_points_list = []
    mean_mse_list = []
    length_scale_list = []

    decay_rate = (min_temp / start_temp) ** (1 / (n_iter - 1))

    # Initialize optimizer
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler()

    # Define pooling layer
    pooling_layer = nn.AvgPool2d(kernel_size=3, stride=1, padding=1)

    # Training loop
    for k in range(n_iter):
        optimizer.zero_grad()
        total_points = 0
        total_mse = 0
        # weight = (1/1)*(k/n_iter)
        # Adjust weight based on the current iteration
        if k < warmup_iterations:
            weight = 0
        else:
            # Calculate weight incrementally after warmup
            weight = min((k - warmup_iterations + 1) * delta_weight, max_weight)
        for i in range(accumulation_steps):
            with autocast():  # Mixed precision training
                mean_loss, normalized_selected_points, loss_mse, length_scale = model(batch, budget_obs=budget_obs, tau=temperature, n_draw=n_draw, weight=weight)
                mean_loss = mean_loss / accumulation_steps  # Normalize loss by accumulation steps
                total_points += normalized_selected_points / accumulation_steps  # Accumulate normalized points
                total_mse += loss_mse / accumulation_steps  # Accumulate MSE loss

            scaler.scale(mean_loss).backward()

        scaler.step(optimizer)
        scaler.update()

        mean_loss_list.append(mean_loss.item())
        mean_points_list.append(total_points.item())
        mean_mse_list.append(total_mse.item())

        temperature = start_temp * (min_temp / start_temp) ** (1 / (n_iter - 1))
        length_scale_list.append(length_scale.detach().cpu().numpy())

    results.append({
        'mean_loss_list': mean_loss_list,
        'mean_points_list': mean_points_list,
        'mean_mse_list': mean_mse_list,
        'length_scale_list': length_scale_list,
        'logits': model.logits.detach().cpu().numpy()
    })

    # Plot results for the last iteration
    plt.figure(figsize=(10, 5))
    plt.plot(mean_loss_list, label='Mean Model Loss')
    plt.xlabel('Iteration')
    plt.ylabel('Mean Model Loss')
    plt.title('Mean Model Loss Over Iterations')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.plot(mean_points_list, label='Mean Normalized Selected Points')
    plt.xlabel('Iteration')
    plt.ylabel('Mean Normalized Selected Points')
    plt.title('Mean Normalized Selected Points Over Iterations')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.plot(mean_mse_list, label='Mean RMSE Loss')
    plt.xlabel('Iteration')
    plt.ylabel('Mean RMSE Loss')
    plt.title('Mean RMSE Loss Over Iterations')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.plot(length_scale_list, label='Length scale')
    plt.xlabel('Iteration')
    plt.ylabel('Length scale')
    plt.title('Length scale Over Iterations')
    plt.legend()
    plt.show()

    # Visualization code (unchanged)
    tensor_tgt = batch.tgt[0,0].detach().cpu().numpy()
    da = xr.DataArray(tensor_tgt)
    da = da * std_tgt + mean_tgt

    plt.figure(figsize=(10, 5))
    plt.title('Observation probability after training')
    plt.imshow(1 - 1 / (1 + np.exp(-model.logits[1, 0, :, :].detach().cpu().numpy())), cmap='viridis', interpolation='nearest', vmin=0, vmax=1)
    plt.colorbar()
    plt.show()

    # logits_init = (torch.zeros((2, time, lat, lon)))
    # logits_init.data[1, :, :, :] = np.log(rate / (1 - rate))
    # plt.figure(figsize=(10, 5))
    # plt.title('Observation probability before training')
    # plt.imshow(1 - 1 / (1 + np.exp(-logits_init[1, 0, :, :].detach().cpu().numpy())), cmap='viridis', interpolation='nearest')
    # plt.colorbar()
    # plt.show()

    # plt.figure(figsize=(10, 5))
    # da.plot()
    # plt.title(f"Sample Values at Time Step {time_step}")
# Out:
# torch.Size([200, 200])
# Parameter containing:
# tensor(25., device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(25., device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(25., device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(25., device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.9000, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.9000, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.9000, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.9000, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.8054, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.8054, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.8054, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.8054, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.7082, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.7082, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.7082, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.7082, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.6101, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.6101, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.6101, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.6101, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.5114, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.5114, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.5114, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.5114, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.4127, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.4127, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.4127, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.4127, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.3129, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.3129, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.3129, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.3129, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.2147, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.2147, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.2147, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.2147, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.1161, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.1161, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.1161, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.1161, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.0236, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.0236, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.0236, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(24.0236, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.9306, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.9306, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.9306, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.9306, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.8406, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.8406, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.8406, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.8406, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.7496, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.7496, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.7496, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.7496, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.6604, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.6604, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.6604, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.6604, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.5717, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.5717, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.5717, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.5717, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4869, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4869, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4869, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4869, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4026, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4026, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4026, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.4026, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.3192, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.3192, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.3192, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.3192, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.2366, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.2366, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.2366, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.2366, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.1598, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.1598, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.1598, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.1598, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0840, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0840, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0840, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0840, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0055, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0055, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0055, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(23.0055, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.9257, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.9257, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.9257, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.9257, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.8449, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.8449, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.8449, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.8449, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.7632, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.7632, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.7632, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.7632, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6835, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6835, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6835, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6835, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6050, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6050, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6050, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.6050, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.5312, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.5312, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.5312, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.5312, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.4570, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.4570, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.4570, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.4570, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3807, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3807, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3807, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3807, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3040, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3040, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3040, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.3040, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.2273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.2273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.2273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.2273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.1544, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.1544, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.1544, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.1544, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0816, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0816, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0816, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0816, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0090, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0090, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0090, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(22.0090, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.9333, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.9333, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.9333, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.9333, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.8565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.8565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.8565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.8565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7798, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7798, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7798, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7798, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.7038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.6240, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.6240, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.6240, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.6240, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.5435, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.5435, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.5435, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.5435, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.4592, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.4592, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.4592, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.4592, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.3740, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.3740, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.3740, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.3740, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.2861, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.2861, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.2861, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.2861, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1083, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1083, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1083, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.1083, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.0158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.0158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.0158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(21.0158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.9191, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.9191, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.9191, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.9191, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.8204, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.8204, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.8204, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.8204, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.7202, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.7202, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.7202, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.7202, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.6184, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.6184, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.6184, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.6184, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.5155, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.5155, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.5155, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.5155, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.4102, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.4102, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.4102, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.4102, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.3038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.3038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.3038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.3038, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.1954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.1954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.1954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.1954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.0848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.0848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.0848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(20.0848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.9731, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.9731, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.9731, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.9731, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.8595, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.8595, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.8595, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.8595, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.7447, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.7447, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.7447, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.7447, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.6282, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.6282, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.6282, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.6282, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.5124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.5124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.5124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.5124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.3951, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.3951, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.3951, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.3951, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.2761, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.2761, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.2761, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.2761, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.1565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.1565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.1565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.1565, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.0359, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.0359, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.0359, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(19.0359, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.9158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.9158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.9158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.9158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.7984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.7984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.7984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.7984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.6810, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.6810, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.6810, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.6810, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.5667, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.5667, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.5667, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.5667, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.4554, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.4554, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.4554, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.4554, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.2404, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.2404, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.2404, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.2404, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.1368, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.1368, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.1368, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.1368, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.0351, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.0351, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.0351, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(18.0351, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.9355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.9355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.9355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.9355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.8384, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.8384, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.8384, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.8384, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.7432, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.7432, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.7432, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.7432, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.6503, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.6503, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.6503, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.6503, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.5596, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.5596, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.5596, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.5596, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.4708, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.4708, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.4708, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.4708, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.3838, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.3838, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.3838, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.3838, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2984, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2148, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2148, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2148, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.2148, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.1330, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.1330, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.1330, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.1330, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.0528, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.0528, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.0528, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(17.0528, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.9742, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.9742, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.9742, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.9742, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8975, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8975, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8975, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8975, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8224, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8224, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8224, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.8224, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.7489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.7489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.7489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.7489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6769, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6769, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6769, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6769, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.6065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.5373, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.5373, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.5373, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.5373, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4698, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4698, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4698, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4698, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4037, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4037, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4037, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.4037, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.3389, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.3389, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.3389, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.3389, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2756, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2756, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2756, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2756, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.2138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.1532, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.1532, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.1532, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.1532, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0939, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0939, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0939, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0939, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0360, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0360, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0360, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(16.0360, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9792, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9792, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9792, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9792, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9234, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9234, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9234, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.9234, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8686, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8686, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8686, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8686, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8145, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8145, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8145, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.8145, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7610, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7610, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7610, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7610, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7079, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7079, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7079, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.7079, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6556, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6556, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6556, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6556, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6035, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6035, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6035, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.6035, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5518, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5518, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5518, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5518, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5004, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5004, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5004, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.5004, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.4489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.4489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.4489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.4489, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3978, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3978, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3978, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3978, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.3466, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2954, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2440, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2440, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2440, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.2440, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1408, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1408, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1408, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.1408, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0889, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0889, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0889, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0889, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0367, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0367, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0367, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(15.0367, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9843, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9843, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9843, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9843, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9318, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9318, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9318, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.9318, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8791, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8791, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8791, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8791, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8263, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8263, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8263, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.8263, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7735, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7735, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7735, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7735, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7208, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7208, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7208, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.7208, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6682, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6682, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6682, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6682, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.6158, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5637, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5637, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5637, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5637, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5119, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5119, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5119, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.5119, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4094, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4094, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4094, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.4094, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3587, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3587, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3587, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3587, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3084, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3084, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3084, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.3084, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2586, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2586, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2586, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2586, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2093, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2093, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2093, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.2093, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1605, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.1124, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0648, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0648, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0648, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0648, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0180, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0180, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0180, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(14.0180, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9716, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9716, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9716, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9716, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9259, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9259, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9259, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.9259, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8808, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8808, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8808, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8808, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8364, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8364, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8364, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.8364, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7925, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7490, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7490, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7490, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7490, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7061, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7061, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7061, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.7061, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6636, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6636, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6636, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6636, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6213, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6213, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6213, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.6213, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5794, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5794, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5794, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5794, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5378, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5378, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5378, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.5378, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4966, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4966, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4966, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4966, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4558, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4558, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4558, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4558, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4153, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4153, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4153, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.4153, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3752, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3752, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3752, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3752, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.3355, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2964, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2964, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2964, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2964, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2578, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2578, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2578, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2578, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2196, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2196, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2196, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.2196, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1818, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1818, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1818, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1818, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1444, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1444, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1444, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1444, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1076, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1076, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1076, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.1076, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0711, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0711, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0711, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0711, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0350, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0350, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0350, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(13.0350, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9995, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9995, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9995, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9995, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9645, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9645, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9645, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9645, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9300, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9300, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9300, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.9300, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8961, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8961, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8961, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8961, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8628, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8628, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8628, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8628, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8298, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8298, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8298, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.8298, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7973, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7973, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7973, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7973, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7654, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7654, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7654, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7654, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7339, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7339, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7339, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7339, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7030, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7030, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7030, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.7030, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6429, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6429, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6429, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6429, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6136, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6136, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6136, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.6136, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5848, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5567, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5567, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5567, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5567, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5289, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5289, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5289, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5289, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5017, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5017, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5017, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.5017, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4750, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4750, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4750, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4750, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4488, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4488, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4488, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4488, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4230, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4230, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4230, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.4230, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3976, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3727, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3481, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3481, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3481, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3481, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3241, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3241, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3241, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3241, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3005, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3005, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3005, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.3005, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2774, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2774, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2774, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2774, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2547, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2547, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2547, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2547, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2323, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2323, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2323, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2323, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2105, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2105, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2105, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.2105, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1891, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1891, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1891, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1891, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1680, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1680, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1680, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1680, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1471, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1471, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1471, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1471, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1267, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1267, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1267, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1267, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.1065, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0865, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0865, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0865, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0865, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0666, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0666, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0666, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0666, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0469, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0469, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0469, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0469, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0273, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0078, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0078, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0078, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(12.0078, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9885, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9885, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9885, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9885, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9695, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9695, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9695, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9695, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9506, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9506, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9506, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9506, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9320, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9320, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9320, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9320, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.9138, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.8955, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.8955, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.8955, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.8955, device='cuda:6', requires_grad=True)
# Parameter containing:
# tensor(11.8774, device='cuda:6', requires_grad=True)

# %%
# Access the last model logits for each iteration of the results
last_logits = [result['logits'] for result in results]

# Access the last value of mean_mse_list for each iteration of the results
last_mean_mse = [result['mean_mse_list'][-1] for result in results]

# Perform the weighted sum of the logits by the inverse of mean MSE
weighted_sum_logits = np.sum([logit for logit, mse in zip(last_logits, last_mean_mse)], axis=0)

# Normalize the weighted sum logits
normalized_logits = weighted_sum_logits / (10)#*np.sum([1 / mse for mse in last_mean_mse]))

weighted_sum = 0
total_weight = 0

for result in results:
    weight = (1 - result['mean_mse_list'][-1])
    logits = result['logits'][-1]
    weighted_sum += weight * logits
    total_weight += weight

if total_weight != 0:
    weighted_average = weighted_sum / total_weight
else:
    weighted_average = 0  # or handle the case where total_weight is 0


# Plot the normalized logits
plt.figure(figsize=(10, 5))
plt.title('Normalized Weighted Sum of Logits')
plt.imshow(logits[0,:, :], cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

plt.figure(figsize=(10, 5))
plt.title('Observation probability after training')
plt.imshow(1 - 1 / (1 + np.exp(-logits[ 0, :, :])), cmap='viridis', interpolation='nearest', vmin=0, vmax=0.01)
plt.colorbar()
plt.show()

# %%
# inp_da_GS = inp_da.isel(lat=slice(crop_lat_start, crop_lat_end),
#                      lon=slice(crop_lon_start, crop_lon_end))

# mean_tgt = inp_da_GS.mean().item()
# std_tgt = inp_da_GS.std().item()

# tens_inp_da = torch.from_numpy(inp_da_GS.values).float().to(device)
# tens_inp_da = (tens_inp_da - mean_tgt) / std_tgt
# tens_inp_da = tens_inp_da.unsqueeze(0)
# tens_inp_da = tens_inp_da.unsqueeze(0)
# tens_inp_da.requires_grad_(True)
# for result in results:
#     logits_warped = torch.from_numpy(result['logits'][-1]).float().to(device)
#     logits_warped = logits_warped.unsqueeze(0)
#     losses_warped = []
#     exp_var_warped = []

#     tau = 1
#     hard = True 
#     padding_size = 10  # Adjust this value as needed

#     time= 1
#     lat, lon =  inp_da_GS.shape
#     tgt_inp = tens_inp_da.clone()

#     for _ in range(100):
#         gs_output = F.gumbel_softmax(logits_warped, hard=True, dim=0)[0, :, :, :]
#         mask_input = gs_output.view(time,lat, lon)
#         mask_input = mask_input.unsqueeze(0).to(device)  # Add batch dimension if necessary
#         mask = mask_input
#         selected_tgt_inp = tgt_inp * mask
#         selected_tgt_inp[mask == 0] = float('nan')
#         # Perform optimal interpolation
#         output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[-1])

#         # Plot the output tensor
#         output_numpy = output.detach().cpu().numpy()
#         tgt_center_numpy = batch.tgt.detach().cpu().numpy()

#         output_numpy_non = (output_numpy * std_tgt) + mean_tgt
#         tgt_center_non = (tgt_center_numpy * std_tgt) + mean_tgt

#         rmse_loss = np.sqrt(np.nanmean((tgt_center_non - output_numpy_non) ** 2))

#         #loss_mse = F.mse_loss(output_center, tgt_center[0,0])
#         losses_warped.append(rmse_loss)

#         # Calculate variance of residuals and actual values
#         residual_variance = np.var(output_numpy_non - tgt_center_non, ddof=1)
#         actual_variance = np.var(tgt_center_non, ddof=1)

#         # Explained Variance
#         explained_variance = 1 - (residual_variance / actual_variance)
#         exp_var_warped.append(explained_variance)
    
#     plt.figure(figsize=(10, 5))
#     plt.title('Observation probability after training')
#     plt.imshow(1 - 1 / (1 + np.exp(-logits[ 0, :, :])), cmap='viridis', interpolation='nearest', vmin=0, vmax=0.01)
#     plt.colorbar()
#     plt.show()
    
#     # Plot histogram of the losses
#     plt.figure(figsize=(10, 5))
#     #plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
#     plt.hist(losses_warped, bins=20, edgecolor='black', color='green')
#     plt.xlabel('Loss')
#     plt.ylabel('Frequency')
#     plt.title('Histogram of RMSE Over 100 samples trained wapred mask')
#     plt.show()

#     # Plot histogram of the losses
#     plt.figure(figsize=(10, 5))
#     #plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
#     plt.hist(exp_var_warped, bins=20, edgecolor='black', color='green')
#     plt.xlabel('Explained variance')
#     plt.ylabel('Frequency')
#     plt.title('Histogram of the explained variance Over 100 samples uniform mask')
#     plt.show()

#     # Print the mean of the losses
#     mean_loss_value_warped = np.mean(losses_warped)
#     print(f"Mean Loss untrained: {mean_loss_value_warped,}")
# Out:
# Mean Loss untrained: (0.12641513,)
# Mean Loss untrained: (0.12641513,)
# Mean Loss untrained: (0.12641513,)
# Mean Loss untrained: (0.12641513,)
# Mean Loss untrained: (0.12641513,)
# Mean Loss untrained: (0.12641513,)
# Mean Loss untrained: (0.12641513,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 34
#      32 selected_tgt_inp[mask == 0] = float('nan')
#      33 # Perform optimal interpolation
# ---> 34 output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[-1])
#      36 # Plot the output tensor
#      37 output_numpy = output.detach().cpu().numpy()
#
# Cell In[4], line 56, in optimal_interpolation(data_with_nans, length_scale, sigma_f, sigma_n)
#      53 K_s = cov_func(observed_coords, missing_coords, length_scale, sigma_f)
#      55 # Cholesky decomposition
# ---> 56 L = torch.cholesky(K + 1e-6 * torch.eye(K.size(0), device=device))  # Add jitter for numerical stability
#      58 # Solve for alpha
#      59 alpha = torch.cholesky_solve(observed_values.unsqueeze(1), L)
#
# KeyboardInterrupt:

# %% [markdown]
# # Results

# %%
data = model.logits[1, 0, :, :].detach().cpu().numpy()
clipped_data = np.clip(data, np.log(0.9/0.1), np.log(0.999/0.01))

# Plot the clipped data
plt.figure(figsize=(10, 5))
plt.title('pos_distribution after training')
plt.imshow(clipped_data, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
gs = F.gumbel_softmax(model.logits[:, 0, :, :], hard=True, dim=0)
datags = gs.detach().cpu().numpy()

# Extract the mask and background data
mask = datags[0]
background = da
# Identify the positions where the mask is one
y_positions, x_positions = np.where(mask == 1)

# Plot the background data
plt.figure(figsize=(10, 5))
plt.title('pos_distribution after training')
plt.imshow(background, cmap='viridis', interpolation='nearest', alpha=0.9)
plt.colorbar()

# Overlay the red dots on the positions where the mask is one
plt.scatter(x_positions, y_positions, color='red', s = 1)
plt.show()

# %%
mask[np.unravel_index((x_positions, y_positions), mask.shape)] = True
structuring_element = disk(lambda_value)

dilated_mask = binary_dilation(mask, structure=structuring_element)
covered_area = np.sum(dilated_mask)
total_area = mask.shape[0] * mask.shape[1]
percentage_covered = (covered_area / total_area) * 100

print(f"Percentage of area covered: {percentage_covered:.2f}%")
# Out:
# Percentage of area covered: 90.70%

# %%
logits = model.logits
logits_warped = torch.tensor(normalized_logits).to(device)

losses_trained = []
exp_var_trained = []
covered_areas_trained = []

losses_warped = []
exp_var_warped = []
covered_areas_warped = []

grid_size = 200
radius = lambda_value
structuring_element = disk(radius)

tau = 1
hard = True 
padding_size = 10  # Adjust this value as needed

time= 1
lat, lon =  inp_da_GS.shape
tgt_inp = tens_inp_da.clone()

logits_inits_init = torch.zeros((2,1,200,200)).to(device)
logits_inits_init[1, :, :, :] = np.log(rate / (1 - rate))
losses_init = []
exp_var_init = []
covered_areas_init = []

for _ in range(100):
    gs_output = F.gumbel_softmax(logits_warped, hard=True, dim=0)[0, :, :, :]
    mask_input = gs_output.view(time,lat, lon)
    mask_input = mask_input.unsqueeze(0).to(device)  # Add batch dimension if necessary
    mask = mask_input
    selected_tgt_inp = tgt_inp * mask
    selected_tgt_inp[mask == 0] = float('nan')
    # Perform optimal interpolation
    output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[-1])

    # Plot the output tensor
    output_numpy = output.detach().cpu().numpy()
    tgt_center_numpy = batch.tgt.detach().cpu().numpy()

    output_numpy_non = (output_numpy * std_tgt) + mean_tgt
    tgt_center_non = (tgt_center_numpy * std_tgt) + mean_tgt

    rmse_loss = np.sqrt(np.nanmean((tgt_center_non - output_numpy_non) ** 2))

    #loss_mse = F.mse_loss(output_center, tgt_center[0,0])
    losses_warped.append(rmse_loss)

    # Calculate variance of residuals and actual values
    residual_variance = np.var(output_numpy_non - tgt_center_non, ddof=1)
    actual_variance = np.var(tgt_center_non, ddof=1)

    # Explained Variance
    explained_variance = 1 - (residual_variance / actual_variance)
    exp_var_warped.append(explained_variance)
    
    # Compute covered area
    mask_np = mask_input.detach().cpu().numpy()[0, 0]
    dilated_mask = dilation(mask_np, structuring_element)
    covered_area = np.sum(dilated_mask)
    total_area = grid_size * grid_size
    percentage_covered = (covered_area / total_area) * 100
    covered_areas_warped.append(percentage_covered)
    
for _ in range(100):
    gs_output = F.gumbel_softmax(logits, hard=True, dim=0)[0, :, :, :]
    mask_input = gs_output.view(time,lat, lon)
    mask_input = mask_input.unsqueeze(0).to(device)  # Add batch dimension if necessary
    mask = mask_input
    selected_tgt_inp = tgt_inp * mask
    selected_tgt_inp[mask == 0] = float('nan')
    # Perform optimal interpolation
    output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[-1])

    # Plot the output tensor
    output_numpy = output.detach().cpu().numpy()
    tgt_center_numpy = batch.tgt.detach().cpu().numpy()

    output_numpy_non = (output_numpy * std_tgt) + mean_tgt
    tgt_center_non = (tgt_center_numpy * std_tgt) + mean_tgt

    rmse_loss = np.sqrt(np.nanmean((tgt_center_non - output_numpy_non) ** 2))

    #loss_mse = F.mse_loss(output_center, tgt_center[0,0])
    losses_trained.append(rmse_loss)

    # Calculate variance of residuals and actual values
    residual_variance = np.var(output_numpy_non - tgt_center_non, ddof=1)
    actual_variance = np.var(tgt_center_non, ddof=1)

    # Explained Variance
    explained_variance = 1 - (residual_variance / actual_variance)
    exp_var_trained.append(explained_variance)
    
    # Compute covered area
    mask_np = mask_input.detach().cpu().numpy()[0, 0]
    dilated_mask = dilation(mask_np, structuring_element)
    covered_area = np.sum(dilated_mask)
    total_area = grid_size * grid_size
    percentage_covered = (covered_area / total_area) * 100
    covered_areas_trained.append(percentage_covered)

for _ in range(100):
    gs_output = F.gumbel_softmax(logits_inits_init, hard=True, dim=0)[0, :, :, :]
    mask_input = gs_output.view(time,lat, lon)
    mask_input = mask_input.unsqueeze(0)  # Add batch dimension if necessary
    mask = mask_input
    selected_tgt_inp = tgt_inp * mask
    selected_tgt_inp[mask == 0] = float('nan')
    # Perform optimal interpolation
    output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[0])

    # Plot the output tensor
    output_numpy = output.detach().cpu().numpy()
    tgt_center_numpy = batch.tgt.detach().cpu().numpy()

    output_numpy_non = (output_numpy * std_tgt) + mean_tgt
    tgt_center_non = (tgt_center_numpy * std_tgt) + mean_tgt

    rmse_loss = np.sqrt(np.nanmean((tgt_center_non - output_numpy_non) ** 2))

    #loss_mse = F.mse_loss(output_center, tgt_center[0,0])
    losses_init.append(rmse_loss)

    # Calculate variance of residuals and actual values
    residual_variance = np.var(output_numpy_non - tgt_center_non, ddof=1)
    actual_variance = np.var(tgt_center_non, ddof=1)

    # Explained Variance
    explained_variance = 1 - (residual_variance / actual_variance)
    exp_var_init.append(explained_variance)
    
    # Compute covered area
    mask_np = mask_input.detach().cpu().numpy()[0, 0]
    dilated_mask = dilation(mask_np, structuring_element)
    covered_area = np.sum(dilated_mask)
    total_area = grid_size * grid_size
    percentage_covered = (covered_area / total_area) * 100
    covered_areas_init.append(percentage_covered)

# Plot histogram of the losses in red
plt.figure(figsize=(10, 5))
plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.title('Histogram of RMSE Over 100 samples trained mask')
plt.show()

# Plot histogram of the losses
plt.figure(figsize=(10, 5))
#plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
plt.hist(losses_init, bins=20, edgecolor='black')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.title('Histogram of RMSE Over 100 samples uniform mask')
plt.show()

# Plot histogram of the losses
plt.figure(figsize=(10, 5))
#plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
plt.hist(losses_warped, bins=20, edgecolor='black', color='green')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.title('Histogram of RMSE Over 100 samples trained wapred mask')
plt.show()

# Plot histogram of the losses
plt.figure(figsize=(10, 5))
plt.hist(losses_warped, bins=20, edgecolor='black', color='green')
plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
plt.hist(losses_init, bins=20, edgecolor='black')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.title('Histogram of RMSE Over 100 samples uniform mask in blue, trained mask in red and warped in green')
plt.show()

# Plot histogram of the losses in red
plt.figure(figsize=(10, 5))
plt.hist(exp_var_trained, bins=20, edgecolor='black', color='red')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.title('Histogram of the explained variance Over 100 samples trained mask')
plt.show()

# Plot histogram of the losses
plt.figure(figsize=(10, 5))
#plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
plt.hist(exp_var_init, bins=20, edgecolor='black')
plt.xlabel('Explained variance')
plt.ylabel('Frequency')
plt.title('Histogram of the explained variance Over 100 samples uniform mask')
plt.show()

# Plot histogram of the losses
plt.figure(figsize=(10, 5))
#plt.hist(losses_trained, bins=20, edgecolor='black', color='red')
plt.hist(exp_var_warped, bins=20, edgecolor='black', color='green')
plt.xlabel('Explained variance')
plt.ylabel('Frequency')
plt.title('Histogram of the explained variance Over 100 samples uniform mask')
plt.show()

# Plot histogram of the losses
plt.figure(figsize=(10, 5))
plt.hist(exp_var_trained, bins=20, edgecolor='black', color='red')
plt.hist(exp_var_init, bins=20, edgecolor='black')
plt.hist(exp_var_warped, bins=20, edgecolor='black', color='green')

plt.xlabel('Explained variance')
plt.ylabel('Frequency')
plt.title('Histogram of the explained variance Over 100 samples uniform mask in blue, trained mask in red and warped in green')
plt.show()

# Print the mean of the losses
mean_loss_value_trained = np.mean(losses_trained)
print(f"Mean Loss trained: {mean_loss_value_trained}")

# Print the mean of the losses
mean_loss_value_init = np.mean(losses_init)
print(f"Mean Loss untrained: {mean_loss_value_init}")

# Print the mean of the losses
mean_loss_value_warped = np.mean(losses_warped)
print(f"Mean Loss untrained: {mean_loss_value_warped,}")

# Trained sampled Generate mask using Gumbel-Softmax
gs_output = F.gumbel_softmax(logits, tau=tau, hard=hard, dim=0)[0, :, :, :]
mask_input = gs_output.view(time,lat, lon)
mask_input = mask_input.unsqueeze(0).to(device)  # Add batch dimension if necessary
normalized_selected_points = mask_input.mean()
# Create mask for observed data
mask = mask_input
# Apply mask to target input
selected_tgt_inp = tgt_inp * mask
selected_tgt_inp[mask == 0] = float('nan')
# Perform optimal interpolation
output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[-1])
# Plot the output tensor
output_numpy = output.detach().cpu().numpy()
tgt_numpy = batch.tgt[0,0].detach().cpu().numpy()

output_numpy_non = (output_numpy * std_tgt) + mean_tgt
tgt_center_non = (tgt_numpy * std_tgt) + mean_tgt

error = (tgt_center_non - output_numpy_non)

rmse = np.sqrt(np.nanmean(error ** 2))
print(f"RMSE: {rmse}")
        
valid_points_mask = ~torch.isnan(selected_tgt_inp)
print(f"Normalized Selected Points: {normalized_selected_points}")

tgt_min = tgt_center_non.min()
tgt_max = tgt_center_non.max()

plt.figure(figsize=(10, 5))
plt.imshow(output_numpy_non, cmap='viridis', vmin=tgt_min, vmax=tgt_max)
plt.colorbar()
plt.title('Trained sampled mask reconstruction')
plt.show()

plt.figure(figsize=(10, 5))
plt.title('Error (Ground Truth - Output)')
plt.imshow(error, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.show()

# Generate mask using Gumbel-Softmax
gs_output_init = F.gumbel_softmax(logits_inits_init, tau=tau, hard=hard, dim=0)[0, :, :, :]
mask_input_init = gs_output_init.view(time,lat, lon)
mask_input_init = mask_input_init.unsqueeze(0)  # Add batch dimension if necessary
normalized_selected_points_init = mask_input_init.mean()
# Create mask for observed data
mask_init = mask_input_init
# Apply mask to target input
selected_tgt_inp_init = tgt_inp * mask_init
selected_tgt_inp_init[mask_init == 0] = float('nan')
# Perform optimal interpolation
output_init = optimal_interpolation(selected_tgt_inp_init[0,0], length_scale=length_scale_list[0])
# Plot the output tensor
output_numpy_init = output_init.detach().cpu().numpy()
tgt_numpy_init = batch.tgt[0,0].detach().cpu().numpy()

output_numpy_non_init  = (output_numpy_init  * std_tgt) + mean_tgt
tgt_center_non_init  = (tgt_numpy_init  * std_tgt) + mean_tgt

error_init  = (tgt_center_non_init  - output_numpy_non_init)

rmse_init = np.sqrt(np.nanmean(error_init ** 2))
print(f"RMSE: {rmse_init }")
        
valid_points_mask_init = ~torch.isnan(selected_tgt_inp_init )
print(f"Normalized Selected Points: {normalized_selected_points_init}")

plt.figure(figsize=(10, 5))
plt.imshow(output_numpy_non_init, cmap='viridis', vmin=tgt_min, vmax=tgt_max)
plt.colorbar()
plt.title('Uniform sampled mask reconstruction')
plt.show()

plt.figure(figsize=(10, 5))
plt.title('Error (Ground Truth - Output)')
plt.imshow(error_init, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.show()

plt.imshow(tgt_center_non_init, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title('Ground Truth')
plt.show()

# Calculate variance of residuals and actual values
residual_variance_init = np.var(output_numpy_non_init - tgt_center_non_init, ddof=1)
actual_variance_init = np.var(tgt_center_non_init, ddof=1)

# Explained Variance
explained_variance_init = 1 - (residual_variance_init / actual_variance_init)

print("Explained Variance Init:", explained_variance_init)

# Calculate variance of residuals and actual values
residual_variance = np.var(output_numpy_non - tgt_center_non, ddof=1)
actual_variance = np.var(tgt_center_non, ddof=1)

# Explained Variance
explained_variance = 1 - (residual_variance / actual_variance)

print("Explained Variance:", explained_variance)


# Count how many uniform samples have RMSE worse than the trained mean RMSE
worse_rmse_count = np.sum(np.array(losses_init) > mean_loss_value_trained)
better_rmse_count = np.sum(np.array(losses_init) < mean_loss_value_trained)
total_uniform_samples = len(losses_init)

percentage_worse_rmse = (worse_rmse_count / total_uniform_samples) * 100
percentage_better_rmse = (better_rmse_count / total_uniform_samples) * 100

print(f"Percentage of uniform RMSE values worse than the trained mean RMSE: {percentage_worse_rmse:.2f}%")
print(f"Percentage of uniform RMSE values better than the trained mean RMSE: {percentage_better_rmse:.2f}%")

# For explained variance, higher values are better.
mean_ev_trained = np.mean(exp_var_trained)
mean_ev_uniform = np.mean(exp_var_init)

# Count how many uniform samples have explained variance worse (i.e., lower) than the trained mean
worse_ev_count = np.sum(np.array(exp_var_init) < mean_ev_trained)
better_ev_count = np.sum(np.array(exp_var_init) > mean_ev_trained)
total_uniform_samples_ev = len(exp_var_init)

percentage_worse_ev = (worse_ev_count / total_uniform_samples_ev) * 100
percentage_better_ev = (better_ev_count / total_uniform_samples_ev) * 100

print(f"Percentage of uniform explained variance values worse than the trained mean EV: {percentage_worse_ev:.2f}%")
print(f"Percentage of uniform explained variance values better than the trained mean EV: {percentage_better_ev:.2f}%")
# Out:
# Mean Loss trained: 0.1468885838985443
# Mean Loss untrained: 0.22690768539905548
# Mean Loss untrained: (1.0257308,)
# RMSE: 0.1466253697872162
# Normalized Selected Points: 0.004999999888241291
# RMSE: 0.2370343655347824
# Normalized Selected Points: 0.004799999762326479
# Explained Variance Init: 0.9472962766885757
# Explained Variance: 0.979829266667366
# Percentage of uniform RMSE values worse than the trained mean RMSE: 100.00%
# Percentage of uniform RMSE values better than the trained mean RMSE: 0.00%
# Percentage of uniform explained variance values worse than the trained mean EV: 100.00%
# Percentage of uniform explained variance values better than the trained mean EV: 0.00%

# %%
# Plot RMSE vs. Covered Area
plt.figure(figsize=(10, 5))
plt.scatter(covered_areas_trained, losses_trained, color='red', edgecolor='k')
plt.xlabel('Percentage of Area Covered (%)')
plt.ylabel('RMSE')
plt.title('RMSE vs. Covered Area')
plt.grid(True)
plt.show()

# Prepare data for regression
X_trained = np.array(covered_areas_trained).reshape(-1, 1)  # Independent variable (Covered Area)
y_trained = np.array(losses_trained)  # Dependent variable (RMSE)

# Fit linear regression model
model_regression = LinearRegression()
model_regression.fit(X_trained, y_trained)
r_squared = model_regression.score(X_trained, y_trained)
print(f"R² Score between Covered Area and RMSE: {r_squared:.4f}")
# Out:
# R² Score between Covered Area and RMSE: 0.0079

# %%
# Plot RMSE vs. Covered Area
plt.figure(figsize=(10, 5))
plt.scatter(covered_areas_init, losses_init, color='blue', edgecolor='k')
plt.xlabel('Percentage of Area Covered (%)')
plt.ylabel('RMSE')
plt.title('RMSE vs. Covered Area')
plt.grid(True)
plt.show()

# Prepare data for regression
X = np.array(covered_areas_init).reshape(-1, 1)  # Independent variable (Covered Area)
y = np.array(losses_init)  # Dependent variable (RMSE)

# Fit linear regression model
model_regression = LinearRegression()
model_regression.fit(X, y)
r_squared = model_regression.score(X, y)
print(f"R² Score between Covered Area and RMSE: {r_squared:.4f}")
# Out:
# R² Score between Covered Area and RMSE: 0.2024

# %%
# Plot RMSE vs. Covered Area
plt.figure(figsize=(10, 5))
plt.scatter(covered_areas_init, losses_init, color='blue', edgecolor='k')
plt.scatter(covered_areas_trained, losses_trained, color='red', edgecolor='k')
plt.xlabel('Percentage of Area Covered (%)')
plt.ylabel('RMSE')
plt.title('RMSE vs. Covered Area')
plt.grid(True)
plt.show()

# %%
plt.imshow((inp_da  - mean_tgt) / std_tgt, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title('GT')
plt.show()

# %%
logits = model.logits

losses_trained = []
covered_areas_trained = []
grid_size = 200
radius = lambda_value
structuring_element = disk(radius)

tau = 1
hard = True 
padding_size = 10  # Adjust this value as needed

time= 1
lat, lon =  inp_da.shape
tgt_inp = tens_inp_da.clone()

# Generate mask using Gumbel-Softmax
gs_output = F.gumbel_softmax(logits, tau=tau, hard=hard, dim=0)[0, :, :, :]
mask_input = gs_output.view(time,lat, lon)
mask_input = mask_input.unsqueeze(0).to(device)  # Add batch dimension if necessary
normalized_selected_points = mask_input.mean()
# Create mask for observed data
mask = mask_input
# Apply mask to target input
selected_tgt_inp = tgt_inp * mask
selected_tgt_inp[mask == 0] = float('nan')
# Perform optimal interpolation
output = optimal_interpolation(selected_tgt_inp[0,0], length_scale=length_scale_list[-1])
# Plot the output tensor
output_numpy = output.detach().cpu().numpy()

plt.imshow((inp_da  - mean_tgt) / std_tgt, cmap='viridis', interpolation='nearest')
plt.colorbar()
plt.title('GT')
plt.show()

vmin = (inp_da - mean_tgt).min() / std_tgt
vmax = (inp_da - mean_tgt).max() / std_tgt

plt.imshow(output_numpy, cmap='viridis', interpolation='nearest', vmin=vmin, vmax=vmax)
plt.colorbar()
plt.title('Output Tensor Plot')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 19
#      17 # Generate mask using Gumbel-Softmax
#      18 gs_output = F.gumbel_softmax(logits, tau=tau, hard=hard, dim=0)[0, :, :, :]
# ---> 19 mask_input = gs_output.view(time,lat, lon)
#      20 mask_input = mask_input.unsqueeze(0).to(device)  # Add batch dimension if necessary
#      21 normalized_selected_points = mask_input.mean()
#
# RuntimeError: shape '[1, 240, 240]' is invalid for input of size 40000
